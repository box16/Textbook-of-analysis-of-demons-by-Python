# %% [markdown]
# 次の式上の二つの点を考える
# $y = \frac{1}{2}x^2$
# ![image.png](attachment:image.png)
#
# この式を微分すると$\frac{dy}{dx} = x$
# つまり、xの値が正の時は正の値をとり、
# 負の時は負の値をとる
#
# これが機械学習では大きな役割を果たす
# 例えば、誤差関数を二乗関数で定義すれば、微分した値が、傾きとなる。
# 傾きが0となるように誤差関数を調整すれば機械学習のパラメータが最適化されるといった具合
